# %%
import pandas as pd     
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\jhont\OneDrive\Escritorio\campamento itec1\nuevo\Areas_cultivadas_y_produccion_agr_cola_en_Antioquia_desde_1990-2022_20250316.csv")
df2 = pd.read_csv(r"Producci_n_de_frutales_en_el_Valle_del_Cauca_20250316.csv")

# %%
df.head()
# Out:
#           Tipo     Rubro Subregion   Año      Municipio  Área Total  \
# 0  Permanentes  Aguacate   Oriente  1990      Abejorral        45.0
# 1  Permanentes  Aguacate     Urabá  1990       Apartadó        29.0
# 2  Permanentes  Aguacate  Suroeste  1990     Montebello        17.0
# 3  Permanentes  Aguacate  Suroeste  1990  Santa Bárbara       150.0
# 4  Permanentes  Aguacate     Urabá  1990          Turbo        75.0
#
#    Área Producción  Volumen Producción
# 0             23.0               138.0
# 1             27.0               405.0
# 2             12.0                78.0
# 3            140.0               980.0
# 4             55.0               825.0

# %%
df2.head()
# Out:
#     año  Id_municipio  Municipio Subregion  Id_cultivo  Cultivo  Ciclo  \
# 0  2022         76233      Dagua       Sur     2045801  Plátano  Anual
# 1  2022         76100    Bolivar     Norte     2045801  Plátano  Anual
# 2  2022         76243  El Aguila     Norte     2045801  Plátano  Anual
# 3  2022         76001       Cali       Sur     2045801  Plátano  Anual
# 4  2022         76275    Florida       Sur     2045801  Plátano  Anual
#
#    Produccion_toneladas
# 0               14088.0
# 1                6578.0
# 2               26000.0
# 3                 186.0
# 4                2124.4
